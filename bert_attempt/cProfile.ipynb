# %%
import pstats
from pstats import SortKey

# %%
p = pstats.Stats('output.pstats')
p.strip_dirs().sort_stats(-1).print_stats()
# Out:
# Wed Feb  3 17:12:29 2021    output.pstats
#
#          11430 function calls (10953 primitive calls) in 0.039 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.039    0.039 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <string>:2(__init__)
#        74    0.000    0.000    0.000    0.000 _VF.py:25(__getattr__)
#        49    0.000    0.000    0.000    0.000 __init__.py:31(__get__)
#       317    0.000    0.000    0.000    0.000 _jit_internal.py:750(is_scripting)
#        24    0.000    0.000    0.001    0.000 activation.py:1188(__init__)
#        24    0.000    0.000    0.001    0.000 activation.py:1197(forward)
#         1    0.000    0.000    0.000    0.000 activation.py:358(forward)
#         1    0.000    0.000    0.000    0.000 configuration_utils.py:264(use_return_dict)
#         1    0.000    0.000    0.000    0.000 container.py:184(__iter__)
# ...
